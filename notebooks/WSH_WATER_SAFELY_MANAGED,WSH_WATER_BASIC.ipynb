# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="ticks")
import math

water_data = pd.read_csv('../data/WSH_WATER_SAFELY_MANAGED,WSH_WATER_BASIC_xmart.csv')
water_data.head()
# Out:
#        Country  \
# 0  Afghanistan
# 1      Albania
# 2      Algeria
# 3      Andorra
# 4       Angola
#
#    2017; Population using at least basic drinking-water services (%); Total  \
# 0                                               67.0
# 1                                               91.0
# 2                                               94.0
# 3                                              100.0
# 4                                               56.0
#
#    2017; Population using at least basic drinking-water services (%); Urban  \
# 0                                               96.0
# 1                                               92.0
# 2                                               95.0
# 3                                              100.0
# 4                                               71.0
#
#    2017; Population using at least basic drinking-water services (%); Rural  \
# 0                                               57.0
# 1                                               90.0
# 2                                               89.0
# 3                                              100.0
# 4                                               27.0
#
#    2017; Population using safely managed drinking-water services (%); Total  \
# 0                                                NaN
# 1                                               70.0
# 2                                                NaN
# 3                                               91.0
# 4                                                NaN
#
#    2017; Population using safely managed drinking-water services (%); Urban  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    2017; Population using safely managed drinking-water services (%); Rural  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    2016; Population using at least basic drinking-water services (%); Total  \
# 0                                               64.0
# 1                                               91.0
# 2                                               94.0
# 3                                              100.0
# 4                                               55.0
#
#    2016; Population using at least basic drinking-water services (%); Urban  \
# 0                                               93.0
# 1                                               92.0
# 2                                               95.0
# 3                                              100.0
# 4                                               71.0
#
#    2016; Population using at least basic drinking-water services (%); Rural  \
# 0                                               55.0
# 1                                               90.0
# 2                                               89.0
# 3                                              100.0
# 4                                               27.0
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    2001; Population using at least basic drinking-water services (%); Rural  \
# 0                                               22.0
# 1                                               82.0
# 2                                               84.0
# 3                                              100.0
# 4                                               22.0
#
#    2001; Population using safely managed drinking-water services (%); Total  \
# 0                                                NaN
# 1                                               49.0
# 2                                                NaN
# 3                                               91.0
# 4                                                NaN
#
#    2001; Population using safely managed drinking-water services (%); Urban  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    2001; Population using safely managed drinking-water services (%); Rural  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    2000; Population using at least basic drinking-water services (%); Total  \
# 0                                               28.0
# 1                                               88.0
# 2                                               90.0
# 3                                              100.0
# 4                                               41.0
#
#    2000; Population using at least basic drinking-water services (%); Urban  \
# 0                                               49.0
# 1                                               96.0
# 2                                               94.0
# 3                                              100.0
# 4                                               61.0
#
#    2000; Population using at least basic drinking-water services (%); Rural  \
# 0                                               22.0
# 1                                               82.0
# 2                                               83.0
# 3                                              100.0
# 4                                               21.0
#
#    2000; Population using safely managed drinking-water services (%); Total  \
# 0                                                NaN
# 1                                               49.0
# 2                                                NaN
# 3                                               91.0
# 4                                                NaN
#
#    2000; Population using safely managed drinking-water services (%); Urban  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    2000; Population using safely managed drinking-water services (%); Rural
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 109 columns]

# %%
water_data_zero_values = water_data.notna()[u'2017; Population using at least basic drinking-water services (%); Total']
water_data_sorted = water_data[water_data_zero_values].sort_values(by=u'2017; Population using at least basic drinking-water services (%); Total', ascending=True)

plt.figure(figsize=(16,6))
waterplot_1 = sns.barplot(x=water_data_sorted['Country'], y=water_data_sorted[u'2017; Population using at least basic drinking-water services (%); Total'], color='#00BFFF')

plt.xticks([]);

# %%
water_data_zero_values_2005 = water_data.notna()[u'2005; Population using at least basic drinking-water services (%); Total']
water_data_sorted_2005 = water_data[water_data_zero_values_2005].sort_values(by=u'2005; Population using at least basic drinking-water services (%); Total', ascending=True)

plt.figure(figsize=(16,6))
waterplot_2 = sns.barplot(x=water_data_sorted_2005['Country'], y=water_data_sorted_2005[u'2005; Population using at least basic drinking-water services (%); Total'], color='#00BFFF')

plt.xticks([]);
